# %%
from bs4 import BeautifulSoup
import html.parser
import json
import csv
import time
import re
import requests

# %%
h = html.parser

# %%
urls = []
with open('Yelp.csv', 'r' ) as csv_file:
    csv_reader = csv.reader(csv_file)
    for line in csv_reader:
        url = str(line[0]).strip()
        urls.append(url)
print(len(urls))
# Out:
# 10357

# %%
print(urls[5])
# Out:
# https://www.yelp.com/biz/22-mile-house-coarsegold

# %%
headers = {
    'authority': 'www.yelp.com',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '" Not;A Brand";v="99", "Google Chrome";v="91", "Chromium";v="91"',
    'sec-ch-ua-mobile': '?0',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.101 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'none',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'accept-language': 'en-US,en;q=0.9,hi;q=0.8',
}

# %%
for i in range(0,len(urls)):
    url = urls[i]
    r = requests.get(url, headers=headers)
    
    status = str(r.status_code).strip()
    
    if status=="503":
        return
    soup = BeautifulSoup(r.text, 'html.parser')
    
    name,address,website,phone,amenities = [""]*5
    
    try:
        name    = str(soup.select_one('h1[class="css-11q1g5y"]').text).strip()
    except:
        pass
    

    try:
        address = str(soup.select_one('address[class]').text).strip()
    except:
        pass


    try:
        sections = soup.select('section[class*="373c0__1TRkQ"]')
        for section in sections:
            label = str(section.select_one('[class="css-16iwlls"]').text).strip()
            if label=="Amenities and More":
                amenities     = ""
                amenities_raw = section.select('[class="css-1h1j0y3"]')
                for amenity in amenities_raw:
                    amenities += str(amenity.text).strip() + ", "
                amenities = amenities.strip(", ")
    except:
        amenities = ""

    items = soup.select('section[class*="b3__373c0__q1DuY"] [class*="2__373c0__3Zpeq"]')
    for item in items:
        try:
            label  = str(item.select_one('[class="css-aml4xx"]').text).strip()
        except:
            label  = ""

        try:
            result  = str(item.select_one('[class="css-1h1j0y3"]').text).strip()
        except:
            result  = ""

        if label=="Business website":
            website = result
        if label=="phone number":
            phone = result

    f_data = [url,name,address,phone,website,amenities]
    with open(f'outputs/{str(i)}_output.csv', 'w', newline='', encoding="utf-8") as new_file:
        csv_writer = csv.writer(new_file)
        csv_writer.writerow(f_data)
# Out:
# 51 200
# 52 200
# 53 200
# 54 200
# 55 200
# 56 200
# 57 200
# 58 200
# 59 200
# 60 200
# 61 200
# 62 200
# 63 200
# 64 200
# 65 200
# 66 200
# 67 200
# 68 200
# 69 200
# 70 200
# 71 200
# 72 200
# 73 200
# 74 200
# 75 200
# 76 200
# 77 200
# 78 200
# 79 200
# 80 200
# 81 200
# 82 200
# 83 200
# 84 200
# 85 200
# 86 200
# 87 200
# 88 200
# 89 200
# 90 200
# 91 200
# 92 200
# 93 200
# 94 200
# 95 200
# 96 200
# 97 200
# 98 200
# 99 200
# 100 200
# 101 200
# 102 200
# 103 200
# 104 200
# 105 200
# 106 200
# 107 200
# 108 200
# 109 200
# 110 200
# 111 200
# 112 200
# 113 200
# 114 200
# 115 200
# 116 200
# 117 200
# 118 200
# 119 200
# 120 200
# 121 200
# 122 200
# 123 200
# 124 200
# 125 200
# 126 200
# 127 200
# 128 200
# 129 200
# 130 200
# 131 200
# 132 200
# 133 200
# 134 200
# 135 200
# 136 200
# 137 200
# 138 200
# 139 200
# 140 200
# 141 200
# 142 200
# 143 200
# 144 200
# 145 200
# 146 200
# 147 200
# 148 200
# 149 200
# 150 200
# 151 200
# 152 200
# 153 200
# 154 200
# 155 200
# 156 200
# 157 200
# 158 200
# 159 200
# 160 200
# 161 200
# 162 200
# 163 200
# 164 200
# 165 200
# 166 200
# 167 200
# 168 200
# 169 200
# 170 200
# 171 200
# 172 200
# 173 200
# 174 200
# 175 200
# 176 200
# 177 200
# 178 200
# 179 200
# 180 200
# 181 200
# 182 200
# 183 200
# 184 200
# 185 200
# 186 200
# 187 200
# 188 200
# 189 200
# 190 200
# 191 200
# 192 200
# 193 200
# 194 200
# 195 200
# 196 200
# 197 200
# 198 200
# 199 200
# 200 200
# 201 200
# 202 200
# 203 200
# 204 200
# 205 200
# 206 200
# 207 200
# 208 200
# 209 200
# 210 200
# 211 503
# 212 503
# 213 503
# 214 503
# 215 503
# 216 503
# 217 503
# 218 503
# 219 503
# 220 503
# 221 503
# 222 503
# 223 503
# 224 503
# 225 503
# 226 503
# 227 503
# 228 503
# 229 503
# 230 503
# 231 503
# 232 503
# 233 503
# 234 503
# 235 503
# 236 503
# 237 503
# 238 503
# 239 503
# 240 503
# 241 503
# 242 503
# 243 503
# 244 503
# 245 503
# 246 503
# 247 503
# 248 503
# 249 503
# 250 503
# 251 503
# 252 503
# 253 503
# 254 503
# 255 503
# 256 503
# 257 503
# 258 503
# 259 503
# 260 503
# 261 503
# 262 503
# 263 503
# 264 503
# 265 503
# 266 503
# 267 503
# 268 503
# 269 503
# 270 503
# 271 503
# 272 503
# 273 503
# 274 503
# 275 503
# 276 503
# 277 503
# 278 503
# 279 503
# 280 503
# 281 503
# 282 503
# 283 503
# 284 503
# 285 503
# 286 503
# 287 503
# 288 503
# 289 503
# 290 503
# 291 503
# 292 503
# 293 503
# 294 503
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-d8ebaf7248ca> in <module>
#       1 for i in range(51,len(urls)):
#       2     url = urls[i]
# ----> 3     r = requests.get(url, headers=headers)
#       4 #     time.sleep(2)
#       5     soup = BeautifulSoup(r.text, 'html.parser')
#
# c:\users\irfan kalam\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# c:\users\irfan kalam\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\users\irfan kalam\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\users\irfan kalam\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\users\irfan kalam\appdata\local\programs\python\python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\users\irfan kalam\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# c:\users\irfan kalam\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# c:\users\irfan kalam\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# c:\users\irfan kalam\appdata\local\programs\python\python39\lib\site-packages\urllib3\connection.py in connect(self)
#     351     def connect(self):
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#     355         tls_in_tls = False
#
# c:\users\irfan kalam\appdata\local\programs\python\python39\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# c:\users\irfan kalam\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84             if source_address:
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#      88
#
# KeyboardInterrupt:

# %%
url = "https://www.yelp.com/biz/76-gas-station-long-beach-3"
r = requests.get(url, headers=headers)
soup = BeautifulSoup(r.text, 'html.parser')

# %%
name    = str(soup.select_one('h1[class="css-11q1g5y"]').text).strip()
address,website,phone,amenities = [""]*4

try:
    address = str(soup.select_one('address[class]').text).strip()
except:
    pass


try:
    sections = soup.select('section[class*="373c0__1TRkQ"]')
    for section in sections:
        label = str(section.select_one('[class="css-16iwlls"]').text).strip()
        if label=="Amenities and More":
            amenities     = ""
            amenities_raw = section.select('[class="css-1h1j0y3"]')
            for amenity in amenities_raw:
                amenities += str(amenity.text).strip() + ", "
            amenities = amenities.strip(", ")
except:
    amenities = ""

items = soup.select('section[class*="b3__373c0__q1DuY"] [class*="2__373c0__3Zpeq"]')
for item in items:
    try:
        label  = str(item.select_one('[class="css-aml4xx"]').text).strip()
    except:
        label  = ""

    try:
        result  = str(item.select_one('[class="css-1h1j0y3"]').text).strip()
    except:
        result  = ""

    if label=="Business website":
        website = result
    if label=="phone number":
        phone = result
    
f_data = [url,name,address,phone,website,amenities]
with open(f'outputs/{str(i)}_output.csv', 'w', newline='', encoding="utf-8") as new_file:
    csv_writer = csv.writer(new_file)
    csv_writer.writerow(f_data)
# Out:
# 20199 Hwy 41Coarsegold, CA 93614

# %%
sections = soup.select('section[class*="373c0__1TRkQ"]')
for section in sections:
    label = str(section.select_one('[class="css-16iwlls"]').text).strip()
    if label=="Amenities and More":
        amenities     = ""
        amenities_raw = section.select('[class="css-1h1j0y3"]')
        for amenity in amenities_raw:
            amenities += str(amenity.text).strip() + ", "
        amenities = amenities.strip(", ")
amenities
# Out:
# 'Offers Takeout, Accepts Credit Cards, Private Lot Parking, Bike Parking'

# %%
name = h1[class="css-11q1g5y"]
website,phone,amenities = [""]*3
items = soup.select('section[class*="b3__373c0__q1DuY"] [class*="2__373c0__3Zpeq"]')
for item in items:
    try:
        label  = str(item.select_one('[class="css-aml4xx"]').text).strip()
    except:
        label  = ""
    
    try:
        result  = str(item.select_one('[class="css-1h1j0y3"]').text).strip()
    except:
        result  = ""
        
    if label=="Business website":
        website = result
    if label=="phone number":
        phone = result
print(website,phone)
# Out:
#  (559) 822-8200

# %%
encid
# Out:
# 'efCDhgPcw_v8jfeDZtWiZQ'

# %%
data
# Out:
# {'$ROOT_QUERY.siteConfig.facebook': {'consumerAppId': '97534753161',
#   '__typename': 'FacebookConfig'},
#  '$ROOT_QUERY.siteConfig': {'facebook': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.siteConfig.facebook',
#    'typename': 'FacebookConfig'},
#   '__typename': 'SiteConfig',
#   'cdnDomain': 's3-media0.fl.yelpcdn.com'},
#  'ROOT_QUERY': {'siteConfig': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.siteConfig',
#    'typename': 'SiteConfig'},
#   'webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}})': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}})',
#    'typename': 'WebConsumerFooter'},
#   'business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"})': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"})',
#    'typename': 'Business'},
#   'country({"code":"en_US"})': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.country({"code":"en_US"})',
#    'typename': 'Country'},
#   'csrfToken({"scope":"/signup/one_click_google"})': '6acbcefac282a3e7dd65d12fe727d6677f37063fa465f88a27861ac3ce3c2330',
#   'thirdPartyConfig': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.thirdPartyConfig',
#    'typename': 'ThirdPartyConfig'},
#   'csrfToken({"scope":"/biz_info_api_v1/efCDhgPcw_v8jfeDZtWiZQ/biz_pricing/update"})': '8350a2946030fb8f90d02b30f82c79cfa39581750f7c362cbbf7ce938ac7969f',
#   'csrfToken({"scope":"/biz_info_api_v1/efCDhgPcw_v8jfeDZtWiZQ/biz_pricing/delete"})': 'b9102e9f5bf4f8821dead11ffc13da14db264aa9702f1b048cd3b1c9ea2991dc',
#   'seoMetadata': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.seoMetadata',
#    'typename': 'SeoMetadata'},
#   'csrfToken({"scope":"biz_photos_vote_form"})': 'd5d1e957e60665bb00e5194d8c9ca5652a3877ddea328ab9eeba8497b28eca51'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0': {'title': 'About',
#   'links': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.0',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.1',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.2',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.3',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.4',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.5',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.6',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.7',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.8',
#     'typename': 'WebConsumerFooterLink'}],
#   '__typename': 'WebConsumerFooterColumn'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.0': {'href': 'https://www.yelp.com/about',
#   'text': 'About Yelp',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.1': {'href': 'https://www.yelp.com/careers/home',
#   'text': 'Careers',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.2': {'href': 'https://www.yelp.com/press',
#   'text': 'Press',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.3': {'href': 'http://yelp-ir.com/',
#   'text': 'Investor Relations',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.4': {'href': 'https://www.yelp.com/guidelines',
#   'text': 'Content Guidelines',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.5': {'href': 'https://www.yelp-support.com/article/Yelp-Accessibility-Statement',
#   'text': 'Accessibility Statement',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.6': {'href': 'https://www.yelp.com/static?p=tos',
#   'text': 'Terms of Service',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.7': {'href': 'https://www.yelp.com/tos/privacy_policy',
#   'text': 'Privacy Policy',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0.links.8': {'href': 'https://www.yelp.com/static?p=tos#third-parties',
#   'text': 'Ad Choices',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1': {'title': 'Discover',
#   'links': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.0',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.1',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.2',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.3',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.4',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.5',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.6',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.7',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.8',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.9',
#     'typename': 'WebConsumerFooterLink'}],
#   '__typename': 'WebConsumerFooterColumn'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.0': {'href': 'https://www.yelp.com/costs',
#   'text': 'Yelp Project Cost Guides',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.1': {'href': 'https://www.yelp.com/collections',
#   'text': 'Collections',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.2': {'href': 'https://www.yelp.com/talk',
#   'text': 'Talk',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.3': {'href': 'https://www.yelp.com/events',
#   'text': 'Events',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.4': {'href': 'https://www.yelp.com/local_yelp',
#   'text': 'The Local Yelp',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.5': {'href': 'https://officialblog.yelp.com/',
#   'text': 'Yelp Blog',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.6': {'href': 'https://www.yelp-support.com/',
#   'text': 'Support',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.7': {'href': 'https://www.yelp.com/yelpmobile?source=footer',
#   'text': 'Yelp Mobile',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.8': {'href': 'https://www.yelp.com/developers?country=US',
#   'text': 'Developers',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1.links.9': {'href': 'https://www.yelp.com/rss',
#   'text': 'RSS',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2': {'title': 'Yelp for Business',
#   'links': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.0',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.1',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.2',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.3',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.4',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.5',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.6',
#     'typename': 'WebConsumerFooterLink'}],
#   '__typename': 'WebConsumerFooterColumn'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.0': {'href': 'https://biz.yelp.com?utm_source=footer&utm_medium=www&utm_content=claim_footer_link&utm_campaign=claim_business',
#   'text': 'Claim your Business Page',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.1': {'href': 'https://www.yelp.com/advertise',
#   'text': 'Advertise on Yelp',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.2': {'href': 'https://restaurants.yelp.com/',
#   'text': 'Yelp for Restaurant Owners',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.3': {'href': 'https://restaurants.yelp.com/products/waitlist-table-management-software/',
#   'text': 'Table Management',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.4': {'href': 'https://biz.yelp.com/support/case_studies',
#   'text': 'Business Success Stories',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.5': {'href': 'https://www.yelp-support.com/Yelp_for_Business_Owners?l=en_US',
#   'text': 'Business Support',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2.links.6': {'href': 'https://www.yelpblog.com/section/business',
#   'text': 'Yelp Blog for Business',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}})': {'desktopColumns': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.0',
#     'typename': 'WebConsumerFooterColumn'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.1',
#     'typename': 'WebConsumerFooterColumn'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).desktopColumns.2',
#     'typename': 'WebConsumerFooterColumn'}],
#   'mobileColumns': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).mobileColumns.0',
#     'typename': 'WebConsumerFooterColumn'}],
#   '__typename': 'WebConsumerFooter'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).mobileColumns.0': {'title': '',
#   'links': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).mobileColumns.0.links.0',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).mobileColumns.0.links.1',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).mobileColumns.0.links.2',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).mobileColumns.0.links.3',
#     'typename': 'WebConsumerFooterLink'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).mobileColumns.0.links.4',
#     'typename': 'WebConsumerFooterLink'}],
#   '__typename': 'WebConsumerFooterColumn'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).mobileColumns.0.links.0': {'href': 'https://www.yelp.com/about',
#   'text': 'About',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).mobileColumns.0.links.1': {'href': 'https://officialblog.yelp.com/',
#   'text': 'Blog',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).mobileColumns.0.links.2': {'href': 'https://www.yelp-support.com/',
#   'text': 'Support',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).mobileColumns.0.links.3': {'href': 'https://www.yelp.com/static?p=tos',
#   'text': 'Terms',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.webConsumerFooter({"baseUrl":"https://www.yelp.com/","urlOptions":{}}).mobileColumns.0.links.4': {'href': 'https://www.yelp.com/tos/privacy_policy',
#   'text': 'Privacy Policy',
#   '__typename': 'WebConsumerFooterLink'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"})': {'name': '76 Pro Wash & Gasoline',
#   'categoryGroups': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categoryGroups',
#    'typename': 'BusinessCategoryGroups'},
#   '__typename': 'Business',
#   'verifiedLicenses': [],
#   'claimability({"useConsumerClaimability":true})': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).claimability({"useConsumerClaimability":true})',
#    'typename': 'BusinessClaimability'},
#   'isCommunityQuestionsEnabled': True,
#   'communityQuestions({"first":2})': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).communityQuestions({"first":2})',
#    'typename': 'BusinessCommunityQuestionConnection'},
#   'consumerAlert': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).consumerAlert',
#    'typename': 'ConsumerAlert'},
#   'reviewCount': 183,
#   'jobPricing': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).jobPricing',
#    'typename': 'JobPricing'},
#   'categories': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.0',
#     'typename': 'BusinessCategory'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.1',
#     'typename': 'BusinessCategory'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.2',
#     'typename': 'BusinessCategory'}],
#   'alias': '76-pro-wash-and-gasoline-fremont',
#   'location': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).location',
#    'typename': 'BusinessLocation'},
#   'containerBusiness': None,
#   'map({"height":180,"width":315})': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).map({"height":180,"width":315})',
#    'typename': 'BusinessMap'},
#   'map({"height":150,"width":315})': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).map({"height":150,"width":315})',
#    'typename': 'BusinessMap'},
#   'serviceArea({"userType":"consumer"})': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).serviceArea({"userType":"consumer"})',
#    'typename': 'BusinessServiceArea'},
#   'claimability': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).claimability',
#    'typename': 'BusinessClaimability'},
#   'hasClaimReminderForCurrentUser': False,
#   'externalResources': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).externalResources',
#    'typename': 'ExternalResources'},
#   'menuVerbiage': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).menuVerbiage',
#    'typename': 'MenuVerbiage'},
#   'yelpMenu': None,
#   'serviceArea': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).serviceArea',
#    'typename': 'BusinessServiceArea'},
#   'meteredPhoneNumber': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).meteredPhoneNumber',
#    'typename': 'BusinessMeteredPhoneNumber'},
#   'phoneNumber': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).phoneNumber',
#    'typename': 'BusinessPhoneNumber'},
#   'shouldHideContactInfoForMultilocationBusinessesExperiment': False,
#   'primaryPhoto': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).primaryPhoto',
#    'typename': 'BusinessPhoto'},
#   'specialties': None,
#   'history': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).history',
#    'typename': 'BusinessHistory'},
#   'serviceUpdateSummary': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).serviceUpdateSummary',
#    'typename': 'BusinessServiceUpdateSummary'},
#   'alternateNames': [],
#   'priceRange': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).priceRange',
#    'typename': 'PriceRange'},
#   'rating': 2.5,
#   'logo': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).logo',
#    'typename': 'BusinessLogo'},
#   'operationHours': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).operationHours',
#    'typename': 'OperationHours'},
#   'closedUntil': None,
#   'authoritativeAttributes': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).authoritativeAttributes',
#    'typename': 'BusinessAuthoritativeAttributes'},
#   'isYelpAdvertiser': False,
#   'media': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).media',
#    'typename': 'BusinessMedia'},
#   'reviews({"first":20})': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20})',
#    'typename': 'ReviewConnection'},
#   'organizedProperties({"clientPlatform":"WWW"})': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0',
#     'typename': 'OrganizedBusinessPropertiesSection'}],
#   'healthInspections': []},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categoryGroups': {'isRFN': True,
#   '__typename': 'BusinessCategoryGroups'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).claimability({"useConsumerClaimability":true})': {'isClaimed': True,
#   '__typename': 'BusinessClaimability',
#   'isClaimable': True,
#   'reason': 'CLAIMABLE_BY_LOCAL_OWNER'},
#  '$ROOT_QUERY.country({"code":"en_US"})': {'gdprCompliant': False,
#   '__typename': 'Country'},
#  '$ROOT_QUERY.thirdPartyConfig.googleAuth({"platform":"WWW"})': {'clientId': '699691895711-vm2k8egb327hq3l0a7crsj0o2o9len61.apps.googleusercontent.com',
#   '__typename': 'GoogleAuthConfig'},
#  '$ROOT_QUERY.thirdPartyConfig': {'googleAuth({"platform":"WWW"})': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.thirdPartyConfig.googleAuth({"platform":"WWW"})',
#    'typename': 'GoogleAuthConfig'},
#   '__typename': 'ThirdPartyConfig'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).communityQuestions({"first":2})': {'totalCount': 0,
#   'edges': [],
#   '__typename': 'BusinessCommunityQuestionConnection'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).consumerAlert': {'isHarsh': None,
#   '__typename': 'ConsumerAlert'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).jobPricing.prices({"jobAliases":["local_moving"],"skipEligibilityCheck":false}).0': {'jobAlias': 'local_moving',
#   'hourlyRate': None,
#   'minimumHours': None,
#   'additionalCostInfo': None,
#   'whatHourlyRateIncludes': None,
#   '__typename': 'JobPrice'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).jobPricing': {'prices({"jobAliases":["local_moving"],"skipEligibilityCheck":false})': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).jobPricing.prices({"jobAliases":["local_moving"],"skipEligibilityCheck":false}).0',
#     'typename': 'JobPrice'}],
#   '__typename': 'JobPricing',
#   'isEligible({"skipAdvertiserCheck":true})': False},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.0.ancestry.0': {'title': 'Automotive',
#   'alias': 'auto',
#   '__typename': 'BusinessCategory'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.0.ancestry.1': {'title': 'Gas Stations',
#   'alias': 'servicestations',
#   '__typename': 'BusinessCategory'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.0': {'ancestry': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.0.ancestry.0',
#     'typename': 'BusinessCategory'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.0.ancestry.1',
#     'typename': 'BusinessCategory'}],
#   '__typename': 'BusinessCategory',
#   'alias': 'servicestations',
#   'title': 'Gas Stations',
#   'root': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.0.root',
#    'typename': 'BusinessCategory'}},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.1.ancestry.0': {'title': 'Automotive',
#   'alias': 'auto',
#   '__typename': 'BusinessCategory'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.1.ancestry.1': {'title': 'Car Wash',
#   'alias': 'carwash',
#   '__typename': 'BusinessCategory'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.1': {'ancestry': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.1.ancestry.0',
#     'typename': 'BusinessCategory'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.1.ancestry.1',
#     'typename': 'BusinessCategory'}],
#   '__typename': 'BusinessCategory',
#   'alias': 'carwash',
#   'title': 'Car Wash',
#   'root': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.1.root',
#    'typename': 'BusinessCategory'}},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.2.ancestry.0': {'title': 'Food',
#   'alias': 'food',
#   '__typename': 'BusinessCategory'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.2.ancestry.1': {'title': 'Convenience Stores',
#   'alias': 'convenience',
#   '__typename': 'BusinessCategory'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.2': {'ancestry': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.2.ancestry.0',
#     'typename': 'BusinessCategory'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.2.ancestry.1',
#     'typename': 'BusinessCategory'}],
#   '__typename': 'BusinessCategory',
#   'alias': 'convenience',
#   'title': 'Convenience Stores',
#   'root': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).categories.2.root',
#    'typename': 'BusinessCategory'}},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).location.address': {'formatted': '34867 Ardenwood Blvd\nFremont, CA 94555',
#   '__typename': 'BusinessAddress',
#   'city': 'Fremont',
#   'regionCode': 'CA',
#   'addressLine1': '34867 Ardenwood Blvd',
#   'addressLine2': '',
#   'addressLine3': '',
#   'postalCode': '94555'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).location': {'address': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).location.address',
#    'typename': 'BusinessAddress'},
#   'neighborhoods': {'type': 'json', 'json': []},
#   'crossStreets': 'Newark Blvd & State Highway 84',
#   'accuracy': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).location.accuracy',
#    'typename': 'GeoAccuracy'},
#   '__typename': 'BusinessLocation',
#   'country': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).location.country',
#    'typename': 'Country'}},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).location.accuracy': {'canShowDirections': True,
#   '__typename': 'GeoAccuracy'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).map({"height":180,"width":315})': {'src': 'https://maps.googleapis.com/maps/api/staticmap?size=315x180&sensor=false&client=gme-yelp&language=en&scale=1&zoom=15&center=37.551404%2C-122.055158&markers=scale%3A1%7Cicon%3Ahttps%3A%2F%2Fyelp-images.s3.amazonaws.com%2Fassets%2Fmap-markers%2Fannotation_32x43.png%7C37.551404%2C-122.055158&signature=-ij8JRjQPdLzub5z6h9k34nFQv0=',
#   'srcSet': 'https://maps.googleapis.com/maps/api/staticmap?size=315x180&sensor=false&client=gme-yelp&language=en&scale=1&zoom=15&center=37.551404%2C-122.055158&markers=scale%3A1%7Cicon%3Ahttps%3A%2F%2Fyelp-images.s3.amazonaws.com%2Fassets%2Fmap-markers%2Fannotation_32x43.png%7C37.551404%2C-122.055158&signature=-ij8JRjQPdLzub5z6h9k34nFQv0= 1x, https://maps.googleapis.com/maps/api/staticmap?size=315x180&sensor=false&client=gme-yelp&language=en&scale=2&zoom=15&center=37.551404%2C-122.055158&markers=scale%3A2%7Cicon%3Ahttps%3A%2F%2Fyelp-images.s3.amazonaws.com%2Fassets%2Fmap-markers%2Fannotation_64x86.png%7C37.551404%2C-122.055158&signature=DL0V3HfcdoPIyGP-8ryedMTz_tY= 2x',
#   'marker': None,
#   '__typename': 'BusinessMap'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).map({"height":150,"width":315})': {'src': 'https://maps.googleapis.com/maps/api/staticmap?size=315x150&sensor=false&client=gme-yelp&language=en&scale=1&zoom=15&center=37.551404%2C-122.055158&markers=scale%3A1%7Cicon%3Ahttps%3A%2F%2Fyelp-images.s3.amazonaws.com%2Fassets%2Fmap-markers%2Fannotation_32x43.png%7C37.551404%2C-122.055158&signature=Fya4Lpymzy7QzOyhCpt2mWPJaaY=',
#   'srcSet': 'https://maps.googleapis.com/maps/api/staticmap?size=315x150&sensor=false&client=gme-yelp&language=en&scale=1&zoom=15&center=37.551404%2C-122.055158&markers=scale%3A1%7Cicon%3Ahttps%3A%2F%2Fyelp-images.s3.amazonaws.com%2Fassets%2Fmap-markers%2Fannotation_32x43.png%7C37.551404%2C-122.055158&signature=Fya4Lpymzy7QzOyhCpt2mWPJaaY= 1x, https://maps.googleapis.com/maps/api/staticmap?size=315x150&sensor=false&client=gme-yelp&language=en&scale=2&zoom=15&center=37.551404%2C-122.055158&markers=scale%3A2%7Cicon%3Ahttps%3A%2F%2Fyelp-images.s3.amazonaws.com%2Fassets%2Fmap-markers%2Fannotation_64x86.png%7C37.551404%2C-122.055158&signature=OEpmDKWkUQ62s5eM96EbEZ1-N0A= 2x',
#   'marker': None,
#   '__typename': 'BusinessMap'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).serviceArea({"userType":"consumer"})': {'eligible': True,
#   'areas': None,
#   'primaryLocation': None,
#   '__typename': 'BusinessServiceArea'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).claimability': {'isClaimable': True,
#   '__typename': 'BusinessClaimability'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).externalResources': {'menuUrl': None,
#   '__typename': 'ExternalResources'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).menuVerbiage': {'noun': 'Offerings',
#   'link': 'View offerings',
#   '__typename': 'MenuVerbiage'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).serviceArea': {'areas': None,
#   '__typename': 'BusinessServiceArea'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).meteredPhoneNumber': {'phoneText': None,
#   '__typename': 'BusinessMeteredPhoneNumber'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).phoneNumber': {'formatted': '(510) 797-7446',
#   '__typename': 'BusinessPhoneNumber'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"})': {'canonicalUrl': 'https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont',
#   'alternateTags': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.0',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.1',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.2',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.3',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.4',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.5',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.6',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.7',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.8',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.9',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.10',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.11',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.12',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.13',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.14',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.15',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.16',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.17',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.18',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.19',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.20',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.21',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.22',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.23',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.24',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.25',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.26',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.27',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.28',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.29',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.30',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.31',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.32',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.33',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.34',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.35',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.36',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.37',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.38',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.39',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.40',
#     'typename': 'AlternateTag'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.41',
#     'typename': 'AlternateTag'}],
#   '__typename': 'BizDetailsSeo',
#   'pageTitle': '76 PRO WASH & GASOLINE - 214 Photos & 183 Reviews - Gas Stations - 34867 Ardenwood Blvd, Fremont, CA - Phone Number',
#   'metaDescription': 'Delivery & Pickup Options - 183 reviews of 76 Pro Wash & Gasoline "This 76 gas station also has a sign that says Fast Break Express & it has a Pro Wash car wash.\n\nI went here for gas after crossing back over the Dumbarton Bridge.  It\'s on the Left-hand side once exiting Newark Blvd, heading on Ardenwood Blvd.\n\nIt\'s across the parking lot from the Jack-in-the-Box.\n\nGas prices on Thurs 1/3/07:\n\n87 gas $3.42\n89 gas $3.53\n91 gas $3.64\n\nI used Pump #11 self unl 8.556G x $3.429 total: $29.34\n\nCredit cards taken.\n\nCoupon for carwash here:\nhttp://www.ardenwood76prowash.com/"'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.0': {'locale': 'en_NZ',
#   'url': 'https://www.yelp.co.nz/biz/76-pro-wash-and-gasoline-fremont',
#   '__typename': 'AlternateTag'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.1': {'locale': 'fi_FI',
#   'url': 'https://fi.yelp.fi/biz/76-pro-wash-and-gasoline-fremont',
#   '__typename': 'AlternateTag'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.2': {'locale': 'en_MY',
#   'url': 'https://en.yelp.my/biz/76-pro-wash-and-gasoline-fremont',
#   '__typename': 'AlternateTag'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.3': {'locale': 'pl_PL',
#   'url': 'https://www.yelp.pl/biz/76-pro-wash-and-gasoline-fremont',
#   '__typename': 'AlternateTag'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.4': {'locale': 'ms_MY',
#   'url': 'https://ms.yelp.my/biz/76-pro-wash-and-gasoline-fremont',
#   '__typename': 'AlternateTag'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.5': {'locale': 'es_AR',
#   'url': 'https://www.yelp.com.ar/biz/76-pro-wash-and-gasoline-fremont',
#   '__typename': 'AlternateTag'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.6': {'locale': 'de_DE',
#   'url': 'https://www.yelp.de/biz/76-pro-wash-and-gasoline-fremont',
#   '__typename': 'AlternateTag'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.7': {'locale': 'zh_TW',
#   'url': 'https://www.yelp.com.tw/biz/76-pro-wash-and-gasoline-fremont',
#   '__typename': 'AlternateTag'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.8': {'locale': 'en_US',
#   'url': 'https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont',
#   '__typename': 'AlternateTag'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.9': {'locale': 'es_MX',
#   'url': 'https://www.yelp.com.mx/biz/76-pro-wash-and-gasoline-fremont',
#   '__typename': 'AlternateTag'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.10': {'locale': 'sv_SE',
#   'url': 'https://www.yelp.se/biz/76-pro-wash-and-gasoline-fremont',
#   '__typename': 'AlternateTag'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.11': {'locale': 'fr_FR',
#   'url': 'https://www.yelp.fr/biz/76-pro-wash-and-gasoline-fremont',
#   '__typename': 'AlternateTag'},
#  '$ROOT_QUERY.seoMetadata.bizDetails({"businessEncid":"efCDhgPcw_v8jfeDZtWiZQ","requestUrl":"https://www.yelp.com/biz/76-pro-wash-and-gasoline-fremont"}).alternateTags.12': {'locale': 'en_CH',
#   'url': 'https://en.yelp.ch/biz/76-pro-wash-and-gasoline-fremont',
# ...
#   '__typename': 'ReviewText'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.15': {'node': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.15.node',
#    'typename': 'Review'},
#   '__typename': 'ReviewEdge'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.16.node.author': {'displayName': 'Jonas S.',
#   '__typename': 'User'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.16.node': {'author': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.16.node.author',
#    'typename': 'User'},
#   'timeCreatedTimestamp': 1459012812,
#   'rating': 4,
#   'text': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.16.node.text',
#    'typename': 'ReviewText'},
#   '__typename': 'Review'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.16.node.text': {'full': "I'm giving these guys 4 stars. And here's why...\n\nThey do a fantastic job cleaning my car because, let's be honest here, I'm pretty lazy. \nBut my main concern is this, they know it's a Saturday...they only have about 10 people running their show. And now that I've been here for about 45 minutes (being in line and now waiting) the line runs all the way to the street which makes it very unsafe for traffic and especially cyclists. \nThat in my opinion is why I will only give them 4. Other than that, try to go on a weekday. Luckily for me I work near by so I can sometimes go. \nSo if you see the line spilling onto the street. Keep going!! You'll be here for at least 1.5-2 hours. \n\n***as I write this I got here at 9:30. It is now 10:18 and my car is next to be cleaned out and almost being worked on. \n\nI'm not bashing these guys. Just want to give everyone a perspective on how busy it can get. \n\nThanks for reading!",
#   '__typename': 'ReviewText'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.16': {'node': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.16.node',
#    'typename': 'Review'},
#   '__typename': 'ReviewEdge'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.17.node.author': {'displayName': 'Kaneshka R.',
#   '__typename': 'User'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.17.node': {'author': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.17.node.author',
#    'typename': 'User'},
#   'timeCreatedTimestamp': 1580146628,
#   'rating': 1,
#   'text': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.17.node.text',
#    'typename': 'ReviewText'},
#   '__typename': 'Review'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.17.node.text': {'full': "I wish I would have read the reviews first so I would never took my car to this junk place, they don't do half of the job what they charge you for basically you should wash it yourself at home and I guarantee you would do 100 times better . I burned my $49 of hard earned cash.",
#   '__typename': 'ReviewText'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.17': {'node': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.17.node',
#    'typename': 'Review'},
#   '__typename': 'ReviewEdge'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.18.node.author': {'displayName': 'Amar K.',
#   '__typename': 'User'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.18.node': {'author': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.18.node.author',
#    'typename': 'User'},
#   'timeCreatedTimestamp': 1559256422,
#   'rating': 3,
#   'text': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.18.node.text',
#    'typename': 'ReviewText'},
#   '__typename': 'Review'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.18.node.text': {'full': "I came here to try this place again but the disappointment me . There is more dirt on my car than the picture has. It total wasn't worth almost $30, thank god i didn't fall for the Deluxe wash probablywould of been the same they would have just made more money out of it. If i do go there again next time I'm getting the $15 one if they are just gonna leave dirt every time. I'll give them one more chance and that's it.",
#   '__typename': 'ReviewText'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.18': {'node': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.18.node',
#    'typename': 'Review'},
#   '__typename': 'ReviewEdge'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.19.node.author': {'displayName': 'Hammad K.',
#   '__typename': 'User'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.19.node': {'author': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.19.node.author',
#    'typename': 'User'},
#   'timeCreatedTimestamp': 1531965222,
#   'rating': 1,
#   'text': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.19.node.text',
#    'typename': 'ReviewText'},
#   '__typename': 'Review'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.19.node.text': {'full': 'I usually don\'t like to write bad reviews about a business this one goes over the top.  For the second time in the same week (last weekend and today which is a weekday). They have a banner right when your car enters for the wash and ladie by the name of Maria "Manager" from what the other employees stated is very rude and disrespectful to all customers. I went up to her at 6:30pm last week and thinking that I will get a car wash since their hours are listed to close at 7:00pm but she ends up closing before 6:30pm. So if you\'re gonna close before the time you stated, than maybe you should not advertise that you are open till 7pm. \n\nI asked Maria for her Managers number and name so I can speak with her and she said "NO, I will NoT give you that information". Went inside to a gentleman by the name of Aldair and asked him for her managers number or just the name so I can speak with them the next tim me I\'m in for fuel and state my issue. He refused to give me the managers number or name and kept making excuses. Finally I went outside and one the employees told me their managers name is "Laura". \n\n\nIn summary, the customer service and overall service is very shitty and you would be better of to go spend your money somewhere else, where the next business owner will appreciate your business. Last Maria should not be anything near a "supervisor or manager" because she doesn\'t have it in her to be a role model or leader at the least!',
#   '__typename': 'ReviewText'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.19': {'node': {'type': 'id',
#    'generated': True,
#    'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.19.node',
#    'typename': 'Review'},
#   '__typename': 'ReviewEdge'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20})': {'edges': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.0',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.1',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.2',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.3',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.4',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.5',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.6',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.7',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.8',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.9',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.10',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.11',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.12',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.13',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.14',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.15',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.16',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.17',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.18',
#     'typename': 'ReviewEdge'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).reviews({"first":20}).edges.19',
#     'typename': 'ReviewEdge'}],
#   '__typename': 'ReviewConnection'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0': {'displayTitle': None,
#   'alias': 'www_platform',
#   'properties': [{'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.0',
#     'typename': 'BusinessProperty'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.1',
#     'typename': 'BusinessProperty'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.2',
#     'typename': 'BusinessProperty'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.3',
#     'typename': 'BusinessProperty'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.4',
#     'typename': 'BusinessProperty'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.5',
#     'typename': 'BusinessProperty'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.6',
#     'typename': 'BusinessProperty'},
#    {'type': 'id',
#     'generated': True,
#     'id': '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.7',
#     'typename': 'BusinessProperty'}],
#   '__typename': 'OrganizedBusinessPropertiesSection'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.0': {'displayText': 'Offers Delivery',
#   'alias': 'RestaurantsDelivery',
#   'isActive': True,
#   'iconName': '24x24_order',
#   '__typename': 'BusinessProperty'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.1': {'displayText': 'No Takeout',
#   'alias': 'RestaurantsTakeOut',
#   'isActive': False,
#   'iconName': '24x24_shopping',
#   '__typename': 'BusinessProperty'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.2': {'displayText': 'Accepts Credit Cards',
#   'alias': 'accepts_credit_cards',
#   'isActive': True,
#   'iconName': None,
#   '__typename': 'BusinessProperty'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.3': {'displayText': 'Accepts Android Pay',
#   'alias': 'accepts_android_pay',
#   'isActive': True,
#   'iconName': None,
#   '__typename': 'BusinessProperty'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.4': {'displayText': 'Accepts Apple Pay',
#   'alias': 'accepts_apple_pay',
#   'isActive': True,
#   'iconName': None,
#   '__typename': 'BusinessProperty'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.5': {'displayText': 'Private Lot Parking',
#   'alias': 'BusinessParking',
#   'isActive': True,
#   'iconName': '24x24_parking',
#   '__typename': 'BusinessProperty'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.6': {'displayText': 'Gender-neutral restrooms',
#   'alias': 'has_gender_neutral_restrooms',
#   'isActive': True,
#   'iconName': '24x24_gender_neutral',
#   '__typename': 'BusinessProperty'},
#  '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.7': {'displayText': 'No Bike Parking',
#   'alias': 'has_bike_parking',
#   'isActive': False,
#   'iconName': '24x24_bicycle',
#   '__typename': 'BusinessProperty'}}

# %%
data[f'$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.1']
# Out:
# {'displayText': 'No Takeout',
#  'alias': 'RestaurantsTakeOut',
#  'isActive': False,
#  'iconName': '24x24_shopping',
#  '__typename': 'BusinessProperty'}

# %%
try:
    encid = str(soup.select_one('[name="yelp-biz-id"]')["content"]).strip()
    data = soup.select_one('script[data-apollo-state]')
    data = h.unescape(str(data.contents[0]).replace("<!--","").replace("-->",""))
    data = json.loads(data)

    amenities = ""
    n=0
    while True:
        try:
            string = '$ROOT_QUERY.business({"encid":"' + encid + '"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.' + str(n)
            amenity = str(data[string]["displayText"]).strip()
            amenities += amenity + ", "
            n+=1
        except:
            break
    amenities = amenities.strip(", ")
except:
    amenities = ""
print(amenities)
# Out:
# Accepts Credit Cards

# %%
'$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.{pr}'.format(pr=n)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-929cbecc38f4> in <module>
# ----> 1 '$ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.{pr}'.format(pr=n)
#
# KeyError: '"encid"'

# %%
string = $ROOT_QUERY.business({"encid":"efCDhgPcw_v8jfeDZtWiZQ"}).organizedProperties({"clientPlatform":"WWW"}).0.properties.1

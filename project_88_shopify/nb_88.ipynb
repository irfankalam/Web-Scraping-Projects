# %%
from bs4 import BeautifulSoup
import html.parser
import json
import csv
import time
import re
import requests

# %%
items = []
with open('Shopify World Data Set Ultimate.csv', 'r', encoding="utf-8") as csv_file:
    csv_reader = csv.reader(csv_file)
    for line in csv_reader:
        c_1 = str(line[0])
        c_2 = str(line[1])
        c_3 = str(line[2])
        c_4 = str(line[3])
        c_5 = str(line[4])
        c_6 = str(line[5])
        
        try:
            c_7 = str(line[6])
        except:
            c_7 = ""
        l_data = [c_1, c_2, c_3, c_4, c_5, c_6, c_7]
        items.append(l_data)
print(len(items))
# Out:
# 13508

# %%
items[0]
# Out:
# ['6568',
#  '211266',
#  'browneyedrose.com',
#  'BrownEyedRose',
#  'https://www.facebook.com/BrownEyedRose/',
#  'https://www.facebook.com/ads/library/?active_status=all&ad_type=all&country=ALL&view_all_page_id=161907740547987',
#  '0']

# %%
for i in range(1640,len(items)):
    item = items[i]
    c_1 = str(item[0])
    c_2 = str(item[1])
    c_3 = str(item[2])
    c_4 = str(item[3])
    c_5 = str(item[4])
    c_6 = str(item[5])

    try:
        c_7 = str(item[6])
    except:
        c_7 = ""
    page_id = c_6.split("page_id=")[-1].strip()

    if page_id=="None":
        f_data = [c_1, c_2, c_3, c_4, c_5, c_6, c_7, "", ""]
        with open('output_88.csv', 'a', newline='', encoding="utf-8") as new_file:
            csv_writer = csv.writer(new_file)
            csv_writer.writerow(f_data)
        print(i,"", "")
        continue

    headers = {
        'authority': 'www.facebook.com',
        'x-fb-lsd': 'AVqGDOvmHSg',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36',
        'sec-ch-ua': '" Not;A Brand";v="99", "Google Chrome";v="91", "Chromium";v="91"',
        'content-type': 'application/x-www-form-urlencoded',
        'accept': '*/*',
        'origin': 'https://www.facebook.com',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': c_6,
        'accept-language': 'en-US,en;q=0.9,hi;q=0.8',
        'cookie': 'fr=0v9giRNE1euQwRNxP..BgskyZ..GC7.1.0.Bgu_WL.; datr=TZW-YBYt8CN7Qtj_fJEhb0Dd; wd=1366x224',
    }

    params = (
        ('countries/[0/]', 'ALL'),
        ('view_all_page_id', page_id),
        ('session_id', 'ab01baf1-c52e-477e-a6b0-d253a37c9f58'),
    )

    data = {
      '__user': '0',
      '__a': '1',
      '__dyn': '7xeUmBz8fXgydwn8K2WnFwRwCwgE98nwgU6C4UKewSAwHxW4E7Sezobohws8O0Boe8hwem0nCqbwgE3awbG782Cwoovy8465o-cw5MKi8wl8G0DE7e2l0FG7o4y0Mo5Wm588Egz82ezUuwl8cUjwdq7em2S2W2K7o721uwa-58co11E6iazo',
      '__csr': '',
      '__req': '2',
      '__hs': '18785.PHASED:DEFAULT.2.0.0.0',
      'dpr': '1',
      '__ccg': 'GOOD',
      '__rev': '1003917902',
      '__s': 'iasjan:ok9a1c:c7fk6u',
      '__hsi': '6971174337694800643-0',
      '__comet_req': '0',
      'lsd': 'AVqGDOvmHSg',
      'jazoest': '2967',
      '__spin_r': '1003917902',
      '__spin_b': 'trunk',
      '__spin_t': '1623103008'
    }

    r = requests.post('https://www.facebook.com/ads/library/async/page_info/', headers=headers, params=params, data=data)
    time.sleep(1)
    try:
        data = json.loads(str(r.text).replace("for (;;);",""))
    except:
        data = ""
    
    try:
        pageInfo = str(data["payload"]["pageInfo"]).strip()
    except:
        pageInfo = "None"
    
    if pageInfo == "None":
        f_data = [c_1, c_2, c_3, c_4, c_5, c_6, c_7, "", ""]
        with open('output_88.csv', 'a', newline='', encoding="utf-8") as new_file:
            csv_writer = csv.writer(new_file)
            csv_writer.writerow(f_data)
        print(i,"", "")
        continue
    
    igFollowers = str(data["payload"]["pageInfo"]["igFollowers"]).strip()
    fbLikes = str(data["payload"]["pageInfo"]["likes"]).strip()


    
    f_data = [c_1, c_2, c_3, c_4, c_5, c_6, c_7, igFollowers, fbLikes]
    with open('output_88.csv', 'a', newline='', encoding="utf-8") as new_file:
        csv_writer = csv.writer(new_file)
        csv_writer.writerow(f_data)

    print(i,igFollowers, fbLikes)
# Out:
# 1640
# 1641 9531 70282
# 1642 25314 1485
# 1643 396 1217
# 1644
# 1645 None 46
# 1646
# 1647 31 142
# 1648 None 86
# 1649 1570 1289
# 1650 None 76971
# 1651 301 5136
# 1652 467355 6286
# 1653 18601 4146
# 1654 367 244
# 1655 None 354
# 1656 3640 920
# 1657
# 1658 15933 3259
# 1659 1831 2706
# 1660 34062 4616
# 1661 79 522
# 1662 438 2426
# 1663 97933 99638
# 1664 59 232
# 1665
# 1666 9491 177
# 1667 1613 44229
# 1668 None 13770
# 1669 None 1
# 1670 29764 103978
# 1671 None 2381
# 1672 None 490
# 1673
# 1674
# 1675 331 1158
# 1676 539949 101302
# 1677 None 909
# 1678 5839 12764
# 1679 18529 21751
# 1680 32135 14729
# 1681 8908 468
# 1682
# 1683 None 28781
# 1684 16605 63271
# 1685 6945 44866
# 1686 1416 5134
# 1687 363 1172
# 1688 None 514
# 1689 17056 18397
# 1690 29793 4037
# 1691 None 4018
# 1692 None 619
# 1693 780 14390
# 1694
# 1695 3505 2927
# 1696 203 17
# 1697 7279 2785
# 1698 1579 5094
# 1699 1482 212
# 1700 8144 6065
# 1701 8301 4166
# 1702 1754 4058
# 1703 724 4421
# ...

# %%
page_id = c_6.split("page_id=")[-1].strip()
page_id
# Out:
# '20409006880'

# %%
data = [c_1, c_2, c_3, c_4, c_5, c_6, c_7, c_8, c_9, c_10, c_11, c_12, c_13, c_14, c_15, c_16, c_17, c_18, c_19, c_20, c_21, c_22, c_23, c_24, c_25]
with open(f'{cwd}\output_86.csv', 'a', newline='', encoding="ansi", errors="ignore") as new_file:
    csv_writer = csv.writer(new_file)
    csv_writer.writerow(data)

# %%
headers = {
    'authority': 'www.facebook.com',
    'x-fb-lsd': 'AVqGDOvmHSg',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36',
    'sec-ch-ua': '" Not;A Brand";v="99", "Google Chrome";v="91", "Chromium";v="91"',
    'content-type': 'application/x-www-form-urlencoded',
    'accept': '*/*',
    'origin': 'https://www.facebook.com',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.facebook.com/ads/library/?active_status=all&ad_type=all&country=ALL&view_all_page_id=774841369193085',
    'accept-language': 'en-US,en;q=0.9,hi;q=0.8',
    'cookie': 'fr=0v9giRNE1euQwRNxP..BgskyZ..GC7.1.0.Bgu_WL.; datr=TZW-YBYt8CN7Qtj_fJEhb0Dd; wd=1366x224',
}

params = (
    ('countries/[0/]', 'ALL'),
    ('view_all_page_id', '774841369193085'),
    ('session_id', 'ab01baf1-c52e-477e-a6b0-d253a37c9f58'),
)

data = {
  '__user': '0',
  '__a': '1',
  '__dyn': '7xeUmBz8fXgydwn8K2WnFwRwCwgE98nwgU6C4UKewSAwHxW4E7Sezobohws8O0Boe8hwem0nCqbwgE3awbG782Cwoovy8465o-cw5MKi8wl8G0DE7e2l0FG7o4y0Mo5Wm588Egz82ezUuwl8cUjwdq7em2S2W2K7o721uwa-58co11E6iazo',
  '__csr': '',
  '__req': '2',
  '__hs': '18785.PHASED:DEFAULT.2.0.0.0',
  'dpr': '1',
  '__ccg': 'GOOD',
  '__rev': '1003917902',
  '__s': 'iasjan:ok9a1c:c7fk6u',
  '__hsi': '6971174337694800643-0',
  '__comet_req': '0',
  'lsd': 'AVqGDOvmHSg',
  'jazoest': '2967',
  '__spin_r': '1003917902',
  '__spin_b': 'trunk',
  '__spin_t': '1623103008'
}

r = requests.post('https://www.facebook.com/ads/library/async/page_info/', headers=headers, params=params, data=data)

# %%
data = json.loads(str(r.text).replace("for (;;);",""))
igFollowers = str(data["payload"]["pageInfo"]["igFollowers"]).strip()
igFollowers
# Out:
# '10036688'

# %%
fbLikes = str(data["payload"]["pageInfo"]["likes"]).strip()
fbLikes
# Out:
# '2185680'
